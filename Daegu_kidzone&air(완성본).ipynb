# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
from urllib.request import urlopen

# %%
url_base = "http://192.168.0.82"
url_sub = "/test4.php"
url =url_base + url_sub

html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <style>
# table{border:1px solid gray; border-collapse:collapse;}
# td{border:1px solid gray;padding:5px;}
# </style>
# </head>
# <body>
# ...

# %%
print(soup.find_all('th'))
# Out:
# [<th>상가업소번호</th>, <th>상호명</th>, <th>상권업종분류명</th>, <th>도로명주소</th>]

# %%
len(soup.find_all('tr'))
# Out:
# 912

# %%
tmp_one = soup.find_all('tr')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_="상호명")
# Out:
# <td class="상호명">브라운스톤어린이집</td>

# %%
tmp_one.find(class_="상가업소번호").get_text()
# Out:
# '4606148'

# %%
상가업소번호 = []
상호명 = []
상권업종분류명 = []
도로명주소 = []


list_soup = soup.find_all('tr')

for item in list_soup:
    상가업소번호.append(item.find(class_='상가업소번호').get_text())
    상호명.append(item.find(class_='상호명').get_text())
    상권업종분류명.append(item.find(class_='상권업종분류명').get_text())
    도로명주소.append(item.find(class_='도로명주소').get_text())

# %%
상가업소번호[:5]
# Out:
# ['4606148', '8076001', '10361846', '10382256', '10398306']

# %%
상호명[:5]
# Out:
# ['브라운스톤어린이집', '강림어린이집', '꼬마시티어린이집', '꼬마대통령어린이집', '퀸즈베이비어린이집']

# %%
len(상가업소번호), len(상호명), len(상권업종분류명), len(도로명주소)
# Out:
# (912, 912, 912, 912)

# %%
data = {'상가업소번호':상가업소번호, '상호명':상호명, '상권업종분류명':상권업종분류명, '도로명주소':도로명주소}
df = pd.DataFrame(data)
df.head()
# Out:
#                       도로명주소    상가업소번호 상권업종분류명        상호명
# 0           대구광역시 북구 내곡로 89   4606148    유아교육  브라운스톤어린이집
# 1      대구광역시 달성군 옥포면 돌미로 51   8076001    유아교육     강림어린이집
# 2          대구광역시 동구 동북로 500  10361846    유아교육   꼬마시티어린이집
# 3  대구광역시 달성군 옥포면 비슬로447길 11  10382256    유아교육  꼬마대통령어린이집
# 4          대구광역시 서구 평리로 236  10398306    유아교육  퀸즈베이비어린이집

# %%
df
# Out:
#                         도로명주소    상가업소번호 상권업종분류명        상호명
# 0             대구광역시 북구 내곡로 89   4606148    유아교육  브라운스톤어린이집
# 1        대구광역시 달성군 옥포면 돌미로 51   8076001    유아교육     강림어린이집
# 2            대구광역시 동구 동북로 500  10361846    유아교육   꼬마시티어린이집
# 3    대구광역시 달성군 옥포면 비슬로447길 11  10382256    유아교육  꼬마대통령어린이집
# 4            대구광역시 서구 평리로 236  10398306    유아교육  퀸즈베이비어린이집
# 5      대구광역시 달서구 송현로7안길 23-22  10407515    유아교육    하모니어린이집
# 6        대구광역시 북구 대현남로2길 40-7  10408767    유아교육     대현어린이집
# 7          대구광역시 남구 대명서로 47-2  10418419    유아교육    해달별어린이집
# 8           대구광역시 서구 달서로5길 29  10425404    유아교육   위즈키즈어린이집
# 9          대구광역시 남구 대명남로 10-2  10504003    유아교육     백설어린이집
# 10       대구광역시 달서구 월배로33길 115  10571821    유아교육    아이린어린이집
# 11           대구광역시 북구 학정동로 10  10606610    유아교육   몬테소리어린이집
# 12       대구광역시 북구 태전로13길 46-2  10643097    유아교육     태현어린이집
# 13         대구광역시 달서구 학산로7길 39  10863398    유아교육  월성무지개어린이집
# 14         대구광역시 북구 동북로31길 30  10898531    유아교육     대우어린이집
# ...

# %%
df = pd.DataFrame(data, columns=['상가업소번호', '상호명', '상권업종분류명', '도로명주소'])
df
# Out:
#        상가업소번호        상호명 상권업종분류명                     도로명주소
# 0     4606148  브라운스톤어린이집    유아교육           대구광역시 북구 내곡로 89
# 1     8076001     강림어린이집    유아교육      대구광역시 달성군 옥포면 돌미로 51
# 2    10361846   꼬마시티어린이집    유아교육          대구광역시 동구 동북로 500
# 3    10382256  꼬마대통령어린이집    유아교육  대구광역시 달성군 옥포면 비슬로447길 11
# 4    10398306  퀸즈베이비어린이집    유아교육          대구광역시 서구 평리로 236
# 5    10407515    하모니어린이집    유아교육    대구광역시 달서구 송현로7안길 23-22
# 6    10408767     대현어린이집    유아교육      대구광역시 북구 대현남로2길 40-7
# 7    10418419    해달별어린이집    유아교육        대구광역시 남구 대명서로 47-2
# 8    10425404   위즈키즈어린이집    유아교육         대구광역시 서구 달서로5길 29
# 9    10504003     백설어린이집    유아교육        대구광역시 남구 대명남로 10-2
# 10   10571821    아이린어린이집    유아교육      대구광역시 달서구 월배로33길 115
# 11   10606610   몬테소리어린이집    유아교육          대구광역시 북구 학정동로 10
# 12   10643097     태현어린이집    유아교육      대구광역시 북구 태전로13길 46-2
# 13   10863398  월성무지개어린이집    유아교육        대구광역시 달서구 학산로7길 39
# 14   10898531     대우어린이집    유아교육        대구광역시 북구 동북로31길 30
# ...

# %%
import folium
import googlemaps
from tqdm import tqdm_notebook

# %%
gmaps_key = "AIzaSyAP1dbfNDOiNi8YsfQenL54GYHOMfKNLNk"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
df.set_index('상가업소번호', inplace=True)
df.head()
# Out:
#                 상호명 상권업종분류명                     도로명주소
# 상가업소번호
# 4606148   브라운스톤어린이집    유아교육           대구광역시 북구 내곡로 89
# 8076001      강림어린이집    유아교육      대구광역시 달성군 옥포면 돌미로 51
# 10361846   꼬마시티어린이집    유아교육          대구광역시 동구 동북로 500
# 10382256  꼬마대통령어린이집    유아교육  대구광역시 달성군 옥포면 비슬로447길 11
# 10398306  퀸즈베이비어린이집    유아교육          대구광역시 서구 평리로 236

# %%
lat = []
lng = []

for n in tqdm_notebook(df.index):
    if df['도로명주소'][n] != 'Multiple':
        target_name = df['도로명주소'][n]+', '+'대구광역시'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# A Jupyter Widget

# %%
lat
# Out:
# [35.9026101,
#  35.7896321,
#  35.88006439999999,
#  35.7908068,
#  35.860811,
#  35.8187504,
#  35.8790351,
#  35.8307903,
#  35.8643058,
#  35.8332752,
#  35.82012539999999,
#  35.9447972,
#  35.9219506,
#  35.8326319,
#  35.9004363,
#  35.8453483,
#  35.8113557,
#  35.8502952,
#  35.8694778,
#  35.8657254,
#  35.9257609,
#  35.837607,
#  35.8212782,
#  35.8273876,
#  35.6960206,
#  35.8698998,
#  35.88982010000001,
#  35.8830468,
#  35.9098887,
#  35.8634764,
#  35.8540385,
#  35.8588107,
#  35.8393424,
#  35.8130551,
#  35.8115411,
#  35.8225379,
#  35.8243242,
#  35.8225494,
#  35.8914432,
#  35.8464621,
#  35.8816405,
#  35.8190698,
#  35.7245394,
#  35.8661791,
#  35.83036120000001,
#  35.8008162,
#  35.9236508,
#  35.8794453,
#  35.8609726,
#  35.7982766,
#  35.8766621,
#  35.8902696,
#  35.7991493,
#  35.9223011,
#  35.8215932,
#  35.8766621,
#  35.8858245,
#  35.8264284,
#  35.8733734,
#  35.8676296,
#  35.7922871,
#  35.8072217,
#  35.872669,
#  35.9609127,
#  35.8201412,
# ...

# %%
df.head()
# Out:
#                 상호명 상권업종분류명                     도로명주소
# 상가업소번호
# 4606148   브라운스톤어린이집    유아교육           대구광역시 북구 내곡로 89
# 8076001      강림어린이집    유아교육      대구광역시 달성군 옥포면 돌미로 51
# 10361846   꼬마시티어린이집    유아교육          대구광역시 동구 동북로 500
# 10382256  꼬마대통령어린이집    유아교육  대구광역시 달성군 옥포면 비슬로447길 11
# 10398306  퀸즈베이비어린이집    유아교육          대구광역시 서구 평리로 236

# %%
df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
#                 상호명 상권업종분류명                     도로명주소        lat         lng
# 상가업소번호
# 4606148   브라운스톤어린이집    유아교육           대구광역시 북구 내곡로 89  35.902610  128.514867
# 8076001      강림어린이집    유아교육      대구광역시 달성군 옥포면 돌미로 51  35.789632  128.463792
# 10361846   꼬마시티어린이집    유아교육          대구광역시 동구 동북로 500  35.880064  128.639470
# 10382256  꼬마대통령어린이집    유아교육  대구광역시 달성군 옥포면 비슬로447길 11  35.790807  128.465422
# 10398306  퀸즈베이비어린이집    유아교육          대구광역시 서구 평리로 236  35.860811  128.548963

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()],zoom_start=11)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()],zoom_start=17)

for n in df.index:
    if df['도로명주소'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], popup=df['상호명'][n]).add_to(mapping)
        
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping.save(r'C:\Users\USER\Desktop\프로젝트\jupyter\map.html')

# %%
air = pd.read_excel(r'C:\Users\USER\Desktop\프로젝트\csv\미세먼지2.xlsx', encoding='utf-8')

# %%
place_name = []
for name in air['측정동']:
    place_name.append('대구광역시'+ str(name))
place_name
# Out:
# ['대구광역시대구광역시 중구 달성로 22길 30',
#  '대구광역시대구광역시 수성구 무학로 209',
#  '대구광역시대구광역시 동구 안심로 49길 70',
#  '대구광역시대구광역시 서구 국채보상로 135',
#  '대구광역시대구광역시 남구 성당로 30길 55',
#  '대구광역시대구광역시 북구 3공단로 14길 31',
#  '대구광역시대구광역시 동구 아양로 37길 92',
#  '대구광역시대구광역시 북구 칠곡중앙대로 52길 56',
#  '대구광역시대구광역시 수성구 국채보상로 1000',
#  '대구광역시대구광역시 달서구 성서공단로 11길 32',
#  '대구광역시대구광역시 달성군 현풍면 현풍중앙로 114-34',
#  '대구광역시대구광역시 수성구 노변공원로 52',
#  '대구광역시대구광역시 달서구 월배로 131']

# %%
import pandas as pd
import pandas as pd
import numpy as np
from urllib.request import urlopen
import folium
import googlemaps

# %%
place_address = []
place_lat = []
place_lng = []

for name in place_name:
    tmp = gmaps.geocode(name, language='ko')
    place_address.append(tmp[0].get("formatted_address"))
    
    tmp_loc = tmp[0].get("geometry")
    
    place_lat.append(tmp_loc['location']['lat'])
    
    place_lng.append(tmp_loc['location']['lng'])
    
    print(name + '-->' + tmp[0].get("formatted_address"))
# Out:
# 대구광역시대구광역시 중구 달성로 22길 30-->대한민국 대구광역시 중구 성내3동 달성로22길 30
# 대구광역시대구광역시 수성구 무학로 209-->대한민국 대구광역시 수성구 지산1동 무학로 209
# 대구광역시대구광역시 동구 안심로 49길 70-->대한민국 대구광역시 동구 안심3.4동 안심로49길 70
# 대구광역시대구광역시 서구 국채보상로 135-->대한민국 대구광역시 서구 상중이동 국채보상로 135
# 대구광역시대구광역시 남구 성당로 30길 55-->대한민국 대구광역시 남구 대명동 성당로30길 55
# 대구광역시대구광역시 북구 3공단로 14길 31-->대한민국 대구광역시 북구 노원동 3공단로14길 31
# 대구광역시대구광역시 동구 아양로 37길 92-->대한민국 대구광역시 동구 신암5동 아양로37길 92
# 대구광역시대구광역시 북구 칠곡중앙대로 52길 56-->대한민국 대구광역시 북구 태전동 칠곡중앙대로52길 56
# 대구광역시대구광역시 수성구 국채보상로 1000-->대한민국 대구광역시 수성구 만촌2동 국채보상로 1000
# 대구광역시대구광역시 달서구 성서공단로 11길 32-->대한민국 대구광역시 달서구 신당동 성서공단로11길 32
# 대구광역시대구광역시 달성군 현풍면 현풍중앙로 114-34-->대한민국 대구광역시 달성군 현풍면 현풍중앙로 114
# 대구광역시대구광역시 수성구 노변공원로 52-->대한민국 대구광역시 수성구 시지동 노변공원로 52
# 대구광역시대구광역시 달서구 월배로 131-->대한민국 대구광역시 달서구 진천동 월배로 131

# %%
air['lat'] = place_lat
air['lng'] = place_lng

# %%
lat = []
lng = []

for n in tqdm_notebook(air.index):
    if air['측정동'][n] != 'Multiple':
        target_name = air['측정동'][n]+', '+'대구광역시'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# A Jupyter Widget

# %%
import json

# %%
geo_path = r'C:\Users\USER\Desktop\프로젝트\jupyter\json\02. skorea_municipalities_geo_simple 2.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))

# %%
import numpy as np

# %%
gu_data = pd.pivot_table(air, index=["구"], values=["일_평균값"], aggfunc=np.mean)
gu_data
# Out:
#          일_평균값
# 구
# 남구   63.000000
# 달서구  21.500000
# 달성군  36.000000
# 동구   53.000000
# 북구   61.500000
# 서구   69.000000
# 수성구  19.333333
# 중구   67.000000

# %%
map = folium.Map(location=[35.87222, 128.60250], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_data, 
               data = gu_data['일_평균값'], 
               columns = [gu_data.index, '일_평균값'],
               fill_color ='YlGn',
               key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()],zoom_start=17)

mapping.choropleth(geo_data=geo_data, 
               data = gu_data['일_평균값'], 
               columns = [gu_data.index, '일_평균값'],
               fill_color ='PuRd',
               key_on = 'feature.id')

for n in df.index:
    if df['도로명주소'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], popup=df['상호명'][n], icon=folium.Icon(color= 'blue', icon='info-sign')).add_to(mapping)
        
for x in air.index:
    if air['측정소'][x] !='Multiple':
        folium.Marker([air['lat'][x], air['lng'][x]], popup=air['측정소'][x], icon=folium.Icon(color= 'green', icon='info-sign')).add_to(mapping)
        
        
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping.save(r'C:\Users\USER\Desktop\프로젝트\jupyter\Daegukid&air.html')
