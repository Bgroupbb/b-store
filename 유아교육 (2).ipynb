# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
 from urllib.request import urlopen

# %%
url_base = "http://192.168.0.82"
url_sub = "/test3.php"
url =url_base + url_sub

html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <style>
# table{border:1px solid gray; border-collapse:collapse;}
# td{border:1px solid gray;padding:5px;}
# </style>
# </head>
# <body>
# ...

# %%
print(soup.find_all('th'))
# Out:
# [<th>상가업소번호</th>, <th>상호명</th>, <th>상권업종분류명</th>, <th>도로명주소</th>, <th>경도</th>, <th>위도</th>]

# %%
len(soup.find_all('tr'))
# Out:
# 912

# %%
tmp_one = soup.find_all('tr')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_="상호명")
# Out:
# <td class="상호명">브라운스톤어린이집</td>

# %%
tmp_one.find(class_="상가업소번호").get_text()
# Out:
# '4606148'

# %%
tmp_one.find(class_="경도").get_text()
# Out:
# '128.514'

# %%
상가업소번호 = []
상호명 = []
상권업종분류명 = []
도로명주소 = []
경도 = []
위도 = []

list_soup = soup.find_all('tr')

for item in list_soup:
    상가업소번호.append(item.find(class_='상가업소번호').get_text())
    상호명.append(item.find(class_='상호명').get_text())
    상권업종분류명.append(item.find(class_='상권업종분류명').get_text())
    도로명주소.append(item.find(class_='도로명주소').get_text())
    경도.append(item.find(class_='경도').get_text())
    위도.append(item.find(class_='위도').get_text())

# %%
상가업소번호[:5]
# Out:
# ['4606148', '8076001', '10361846', '10382256', '10398306']

# %%
상호명[:5]
# Out:
# ['브라운스톤어린이집', '강림어린이집', '꼬마시티어린이집', '꼬마대통령어린이집', '퀸즈베이비어린이집']

# %%
len(상가업소번호), len(상호명), len(상권업종분류명), len(도로명주소), len(경도), len(위도),
# Out:
# (912, 912, 912, 912, 912, 912)

# %%
data = {'상가업소번호':상가업소번호, '상호명':상호명, '상권업종분류명':상권업종분류명, '도로명주소':도로명주소, 'lng':경도, 'lat':위도}
df = pd.DataFrame(data)
df.head()
# Out:
#        lat      lng                     도로명주소    상가업소번호 상권업종분류명        상호명
# 0   35.902  128.514           대구광역시 북구 내곡로 89   4606148    유아교육  브라운스톤어린이집
# 1  35.7801   128.44      대구광역시 달성군 옥포면 돌미로 51   8076001    유아교육     강림어린이집
# 2  35.8798  128.639          대구광역시 동구 동북로 500  10361846    유아교육   꼬마시티어린이집
# 3  35.7907  128.465  대구광역시 달성군 옥포면 비슬로447길 11  10382256    유아교육  꼬마대통령어린이집
# 4  35.8616  128.549          대구광역시 서구 평리로 236  10398306    유아교육  퀸즈베이비어린이집

# %%
df
# Out:
#          lat      lng                     도로명주소    상가업소번호 상권업종분류명        상호명
# 0     35.902  128.514           대구광역시 북구 내곡로 89   4606148    유아교육  브라운스톤어린이집
# 1    35.7801   128.44      대구광역시 달성군 옥포면 돌미로 51   8076001    유아교육     강림어린이집
# 2    35.8798  128.639          대구광역시 동구 동북로 500  10361846    유아교육   꼬마시티어린이집
# 3    35.7907  128.465  대구광역시 달성군 옥포면 비슬로447길 11  10382256    유아교육  꼬마대통령어린이집
# 4    35.8616  128.549          대구광역시 서구 평리로 236  10398306    유아교육  퀸즈베이비어린이집
# 5    35.8189  128.549    대구광역시 달서구 송현로7안길 23-22  10407515    유아교육    하모니어린이집
# 6     35.879  128.605      대구광역시 북구 대현남로2길 40-7  10408767    유아교육     대현어린이집
# 7    35.8308   128.56        대구광역시 남구 대명서로 47-2  10418419    유아교육    해달별어린이집
# 8    35.8643  128.568         대구광역시 서구 달서로5길 29  10425404    유아교육   위즈키즈어린이집
# 9    35.8333   128.56        대구광역시 남구 대명남로 10-2  10504003    유아교육     백설어린이집
# 10   35.8201  128.527      대구광역시 달서구 월배로33길 115  10571821    유아교육    아이린어린이집
# ...

# %%
df = pd.DataFrame(data, columns=['상가업소번호', '상호명', '상권업종분류명', '도로명주소', 'lat', 'lng'])
df
# Out:
#        상가업소번호        상호명 상권업종분류명                     도로명주소      lat      lng
# 0     4606148  브라운스톤어린이집    유아교육           대구광역시 북구 내곡로 89   35.902  128.514
# 1     8076001     강림어린이집    유아교육      대구광역시 달성군 옥포면 돌미로 51  35.7801   128.44
# 2    10361846   꼬마시티어린이집    유아교육          대구광역시 동구 동북로 500  35.8798  128.639
# 3    10382256  꼬마대통령어린이집    유아교육  대구광역시 달성군 옥포면 비슬로447길 11  35.7907  128.465
# 4    10398306  퀸즈베이비어린이집    유아교육          대구광역시 서구 평리로 236  35.8616  128.549
# 5    10407515    하모니어린이집    유아교육    대구광역시 달서구 송현로7안길 23-22  35.8189  128.549
# 6    10408767     대현어린이집    유아교육      대구광역시 북구 대현남로2길 40-7   35.879  128.605
# 7    10418419    해달별어린이집    유아교육        대구광역시 남구 대명서로 47-2  35.8308   128.56
# 8    10425404   위즈키즈어린이집    유아교육         대구광역시 서구 달서로5길 29  35.8643  128.568
# 9    10504003     백설어린이집    유아교육        대구광역시 남구 대명남로 10-2  35.8333   128.56
# 10   10571821    아이린어린이집    유아교육      대구광역시 달서구 월배로33길 115  35.8201  128.527
# ...

# %%
import folium
import googlemaps
from tqdm import tqdm_notebook

# %%
gmaps_key = "AIzaSyAP1dbfNDOiNi8YsfQenL54GYHOMfKNLNk"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
df.set_index('상가업소번호', inplace=True)
df.head()
# Out:
#                 상호명 상권업종분류명                     도로명주소      lat      lng
# 상가업소번호
# 4606148   브라운스톤어린이집    유아교육           대구광역시 북구 내곡로 89   35.902  128.514
# 8076001      강림어린이집    유아교육      대구광역시 달성군 옥포면 돌미로 51  35.7801   128.44
# 10361846   꼬마시티어린이집    유아교육          대구광역시 동구 동북로 500  35.8798  128.639
# 10382256  꼬마대통령어린이집    유아교육  대구광역시 달성군 옥포면 비슬로447길 11  35.7907  128.465
# 10398306  퀸즈베이비어린이집    유아교육          대구광역시 서구 평리로 236  35.8616  128.549

# %%
df['lat'].head()
# Out:
# 상가업소번호
# 4606148      35.902
# 8076001     35.7801
# 10361846    35.8798
# 10382256    35.7907
# 10398306    35.8616
# Name: lat, dtype: object

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], zoom_start=11), folium.Marker([df['lat'].mean(), df['lng'].mean()], popup='center').add_to(mapping)
mapping
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     767         try:
# --> 768             x = float(x)
#     769         except Exception:
#
# ...
