# %%
import matplotlib.pyplot as plt

# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 

import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r'C:\Users\USER\Desktop\프로젝트\csv\그래프용\대구\대구오염.xls', encoding = 'utf-8')

# %%
pv = pd.pivot_table(df, index=['시군구'], columns=["배출원대분류"], values=['PM10'], aggfunc=sum, fill_value=0)
pv
# Out:
#           PM10                                                             \
# 배출원대분류 기타 면오염원 농업 도로이동오염원 비도로이동오염원 비산업 연소 생물성 연소 생산공정 에너지산업 연소 에너지수송 및 저장
# 시군구
# 남구         536  0   13882     7634   4705   3413    4        0          0
# 달서구       2452  0   65716    27299  10024  13564  451     1924          0
# 달성군       1344  0   60471    60033   4638  33876  406      186          0
# 동구        1468  0   70685    44762   9495  34295  123    15222          0
# 북구        2218  0  101365    29304   8108  14145  191        0          0
# 서구        1147  0   22292     7142   5014   4283   43    15782          0
# 수성구       1376  0   47767    15315   7329  17950    9        0          0
# 중구         604  0   12364     9433   2962   4287   28        0          0
#
#
# 배출원대분류 유기용제 사용  제조업 연소 폐기물처리
# 시군구
# 남구           0       0     0
# 달서구          0     772  2298
# 달성군          0    1447  4222
# 동구           0      30     0
# 북구           0    1065     0
# 서구           0  677017  1109
# ...

# %%
daegupo = pd.read_excel (r'C:\Users\USER\Desktop\프로젝트\csv\그래프용\대구\구별오염측정PM10.xls')
daegupo
# Out:
#    시군구  기타 면오염원  도로이동오염원  비도로이동오염원  비산업 연소  생물성 연소  생산공정  에너지산업 연소  제조업 연소  \
# 0   남구      536    13882      7634    4705    3413     4         0       0
# 1  달서구     2452    65716     27299   10024   13564   451      1924     772
# 2  달성군     1344    60471     60033    4638   33876   406       186    1447
# 3   동구     1468    70685     44762    9495   34295   123     15222      30
# 4   북구     2218   101365     29304    8108   14145   191         0    1065
# 5   서구     1147    22292      7142    5014    4283    43     15782  677017
# 6  수성구     1376    47767     15315    7329   17950     9         0      30
# 7   중구      604    12364      9433    2962    4287    28         0       9
#
#    폐기물처리
# 0      0
# 1   2298
# 2   4222
# 3      0
# 4      0
# 5   1109
# 6      0
# 7      0

# %%
daegupo['기타면오염원'] = daegupo['기타 면오염원']/1000
daegupo['도로이동 오염원'] = daegupo['도로이동오염원']/1000
daegupo['비도로이동 오염원'] = daegupo['비도로이동오염원']/1000
daegupo['비산업연소'] = daegupo['비산업 연소']/1000
daegupo['생물성연소'] = daegupo['생물성 연소']/1000
daegupo['생산 공정'] = daegupo['생산공정']/1000
daegupo['에너지산업연소'] = daegupo['에너지산업 연소']/1000
daegupo['제조업연소'] = daegupo['제조업 연소']/1000
daegupo['폐기물 처리'] = daegupo['폐기물처리']/1000

del daegupo['기타 면오염원']
del daegupo['도로이동오염원']
del daegupo['비도로이동오염원']
del daegupo['비산업 연소']
del daegupo['생물성 연소']
del daegupo['생산공정']
del daegupo['에너지산업 연소']
del daegupo['제조업 연소']
del daegupo['폐기물처리']

# %%
daegupo
# Out:
#    시군구  기타면오염원  도로이동 오염원  비도로이동 오염원   비산업연소   생물성연소  생산 공정  에너지산업연소    제조업연소  \
# 0   남구   0.536    13.882      7.634   4.705   3.413  0.004    0.000    0.000
# 1  달서구   2.452    65.716     27.299  10.024  13.564  0.451    1.924    0.772
# 2  달성군   1.344    60.471     60.033   4.638  33.876  0.406    0.186    1.447
# 3   동구   1.468    70.685     44.762   9.495  34.295  0.123   15.222    0.030
# 4   북구   2.218   101.365     29.304   8.108  14.145  0.191    0.000    1.065
# 5   서구   1.147    22.292      7.142   5.014   4.283  0.043   15.782  677.017
# 6  수성구   1.376    47.767     15.315   7.329  17.950  0.009    0.000    0.030
# 7   중구   0.604    12.364      9.433   2.962   4.287  0.028    0.000    0.009
#
#    폐기물 처리
# 0   0.000
# 1   2.298
# 2   4.222
# 3   0.000
# 4   0.000
# 5   1.109
# 6   0.000
# 7   0.000

# %%
daegupo['총합'] = daegupo['기타면오염원']+daegupo['도로이동 오염원']+daegupo['비도로이동 오염원']+daegupo['비산업연소']+daegupo['생물성연소']+daegupo['생산 공정']+ \
                  daegupo['에너지산업연소']+daegupo['제조업연소']+daegupo['폐기물 처리']

# %%
daegupo
# Out:
#    시군구  기타면오염원  도로이동 오염원  비도로이동 오염원   비산업연소   생물성연소  생산 공정  에너지산업연소    제조업연소  \
# 0   남구   0.536    13.882      7.634   4.705   3.413  0.004    0.000    0.000
# 1  달서구   2.452    65.716     27.299  10.024  13.564  0.451    1.924    0.772
# 2  달성군   1.344    60.471     60.033   4.638  33.876  0.406    0.186    1.447
# 3   동구   1.468    70.685     44.762   9.495  34.295  0.123   15.222    0.030
# 4   북구   2.218   101.365     29.304   8.108  14.145  0.191    0.000    1.065
# 5   서구   1.147    22.292      7.142   5.014   4.283  0.043   15.782  677.017
# 6  수성구   1.376    47.767     15.315   7.329  17.950  0.009    0.000    0.030
# 7   중구   0.604    12.364      9.433   2.962   4.287  0.028    0.000    0.009
#
#    폐기물 처리       총합
# 0   0.000   30.174
# 1   2.298  124.500
# 2   4.222  166.623
# 3   0.000  176.080
# 4   0.000  156.396
# 5   1.109  733.829
# 6   0.000   89.776
# 7   0.000   29.687

# %%
labels = ['남구', '달서구', '달성군', '동구', '북구', '서구', '수성구', '중구' ]
sizes = [30.174, 124.500, 166.623, 176.080, 156.396, 733.829, 89.776, 29.687]
explode = (0.2, 0, 0, 0, 0, 0, 0, 0.1)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 

plt.title ('구별 PM10 비율')
plt.tight_layout()
plt.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
pv2 = pd.pivot_table(df, index=['시군구'], columns=["배출원대분류"], values=['PM2.5'], aggfunc=sum, fill_value=0)

# %%
pv2
# Out:
#          PM2.5                                                             \
# 배출원대분류 기타 면오염원 농업 도로이동오염원 비도로이동오염원 비산업 연소 생물성 연소 생산공정 에너지산업 연소 에너지수송 및 저장
# 시군구
# 남구         483  0   12769     7024   3049   2909    4        0          0
# 달서구       2207  0   60459    25115   5474  11325  402      748          0
# 달성군       1208  0   55633    55231   3033  27550  319      186          0
# 동구        1322  0   65029    41179   6300  28922  110    15222          0
# 북구        1997  0   93255    26957   5855  11693  172        0          0
# 서구        1032  0   20508     6572   3284   3589   39    12730          0
# 수성구       1238  0   43944    14089   5512  14451    8        0          0
# 중구         544  0   11374     8678   1801   3821   23        0          0
#
#
# 배출원대분류 유기용제 사용  제조업 연소 폐기물처리
# 시군구
# 남구           0       0     0
# 달서구          0     685  1768
# 달성군          0     966  3800
# 동구           0      15     0
# 북구           0     753     0
# 서구           0  236140   998
# ...

# %%
PM25 = pd.read_excel(r'C:\Users\USER\Desktop\프로젝트\csv\그래프용\대구\PM25.xls')

# %%
PM25
# Out:
#    시군구  기타 면오염원  도로이동오염원  비도로이동오염원  비산업 연소  생물성 연소  생산공정  에너지산업 연소  제조업 연소  \
# 0   남구      483    12769      7024    3049    2909     4         0       0
# 1  달서구     2207    60459     25115    5474   11325   402       748     685
# 2  달성군     1208    55633     55231    3033   27550   319       186     966
# 3   동구     1322    65029     41179    6300   28922   110     15222      15
# 4   북구     1997    93255     26957    5855   11693   172         0     753
# 5   서구     1032    20508      6572    3284    3589    39     12730  236140
# 6  수성구     1238    43944     14089    5512   14451     8         0      17
# 7   중구      544    11374      8678    1801    3821    23         0       8
#
#    폐기물처리
# 0      0
# 1   1768
# 2   3800
# 3      0
# 4      0
# 5    998
# 6      0
# 7      0

# %%
PM25['기타면오염원'] = PM25['기타 면오염원']/1000
PM25['도로이동 오염원'] = PM25['도로이동오염원']/1000
PM25['비도로이동 오염원'] = PM25['비도로이동오염원']/1000
PM25['비산업연소'] = PM25['비산업 연소']/1000
PM25['생물성연소'] = PM25['생물성 연소']/1000
PM25['생산 공정'] = PM25['생산공정']/1000
PM25['에너지산업연소'] = PM25['에너지산업 연소']/1000
PM25['제조업연소'] = PM25['제조업 연소']/1000
PM25['폐기물 처리'] = PM25['폐기물처리']/1000

del PM25['기타 면오염원']
del PM25['도로이동오염원']
del PM25['비도로이동오염원']
del PM25['비산업 연소']
del PM25['생물성 연소']
del PM25['생산공정']
del PM25['에너지산업 연소']
del PM25['제조업 연소']
del PM25['폐기물처리']

# %%
PM25['총합'] = PM25['기타면오염원']+PM25['도로이동 오염원']+PM25['비도로이동 오염원']+PM25['비산업연소']+PM25['생물성연소']+PM25['생산 공정']+ \
                  PM25['에너지산업연소']+PM25['제조업연소']+PM25['폐기물 처리']

# %%
PM25
# Out:
#    시군구  기타면오염원  도로이동 오염원  비도로이동 오염원  비산업연소   생물성연소  생산 공정  에너지산업연소    제조업연소  \
# 0   남구   0.483    12.769      7.024  3.049   2.909  0.004    0.000    0.000
# 1  달서구   2.207    60.459     25.115  5.474  11.325  0.402    0.748    0.685
# 2  달성군   1.208    55.633     55.231  3.033  27.550  0.319    0.186    0.966
# 3   동구   1.322    65.029     41.179  6.300  28.922  0.110   15.222    0.015
# 4   북구   1.997    93.255     26.957  5.855  11.693  0.172    0.000    0.753
# 5   서구   1.032    20.508      6.572  3.284   3.589  0.039   12.730  236.140
# 6  수성구   1.238    43.944     14.089  5.512  14.451  0.008    0.000    0.017
# 7   중구   0.544    11.374      8.678  1.801   3.821  0.023    0.000    0.008
#
#    폐기물 처리       총합
# 0   0.000   26.238
# 1   1.768  108.183
# 2   3.800  147.926
# 3   0.000  158.099
# 4   0.000  140.682
# 5   0.998  284.892
# 6   0.000   79.259
# 7   0.000   26.249

# %%
sizes2 = [26.238, 108.183, 147.926, 158.099, 140.682, 284.892, 79.259, 26.249]
explode = (0.2, 0, 0, 0, 0, 0, 0, 0.1)

plt.figure(figsize=(20, 15))
fig2, ax2 = plt.subplots()
ax2.pie(sizes2, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax2.axis('equal') 

plt.title ('구별 PM2.5배출 비율')
plt.tight_layout()
plt.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
daegupo = pd.read_excel(r'C:\Users\USER\Desktop\프로젝트\csv\그래프용\대구\daegupo.xls')
daegupo
# Out:
#         오염물질     PM10    PM2.5
# 0     기타면오염원   11.145   10.031
# 1   도로이동 오염원  394.542  362.971
# 2  비도로이동 오염원  200.922  184.845
# 3      비산업연소   52.275   34.308
# 4      생물성연소  125.813  104.260
# 5      생산 공정    1.255    1.077
# 6    에너지산업연소   33.114   28.886
# 7      제조업연소  680.370  238.584
# 8     폐기물 처리    7.629    6.566

# %%
width = 0.3
N = 9
ind = np.arange(N)

data1 = daegupo['PM10']
data2 = daegupo['PM2.5']

plt.figure(figsize=(7, 6))
p1 = plt.bar(ind+0.00, data1, width, color='y')
p2 = plt.bar(ind+0.33, data2, width, color='r')

plt.xlabel('미세먼지배출종류')
plt.ylabel('배출량')
plt.title('대구시 미세먼지 배출(2015년 기준)')
plt.xticks(ind+width/2., ('기타', '도로', '비도로', '비산업', '생물성', '생산', '에너지', '제조업', '폐기물'))
plt.legend((p1[0], p2[0]), ('PM10', 'PM2.5'))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
labels = ['기타', '도로', '비도로', '비산업', '생물성', '생산공정', '에너지', '제조', '폐기물' ]
sizes3 = [11.145, 394.542, 200.922, 52.275, 125.813, 1.255, 33.114, 680.370, 7.629 ]
explode = (0.3, 0, 0, 0, 0, 0.3, 0.1, 0, 0.1)
fig3, ax3 = plt.subplots()
ax3.pie(sizes3, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax3.axis('equal') 

plt.title ('대구 오염원 비중(PM10)')
plt.tight_layout()
plt.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
labels = ['기타', '도로', '비도로', '비산업', '생물성', '생산공정', '에너지', '제조', '폐기물' ]
sizes4 = [10.031, 362.971, 184.845, 34.308, 104.260, 1.077, 28.886, 238.584, 6.566 ]
explode = (0.3, 0, 0, 0, 0, 0.3, 0.1, 0, 0.1)
fig4, ax4 = plt.subplots()
ax4.pie(sizes4, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax4.axis('equal') 

plt.title ('대구 오염원 비중(PM2.5)')
plt.tight_layout()
plt.legend(labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
